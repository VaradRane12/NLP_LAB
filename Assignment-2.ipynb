# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
import nltk

nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to /Users/varad/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/varad/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')

text = "Natural language processing is interesting"
tokens = word_tokenize(text)
tags = pos_tag(tokens)

print(tags)
# Out:
# [('Natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('is', 'VBZ'), ('interesting', 'VBG')]
# [nltk_data] Downloading package punkt_tab to /Users/varad/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/varad/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemma = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /Users/varad/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
texts = """
    Natural language processing is interesting,
    In LAB 5311LA
"""
tokens = word_tokenize(texts)
pos_tags = pos_tag(tokens)

print(f"\nText: {texts}")
print("POS Tags:")
for word, tag in pos_tags:
    print(f"{word:15} {tag}")
# Out:
# Text:
#     Natural language processing is interesting,
#     In LAB 5311LA
#
# POS Tags:
# Natural         JJ
# language        NN
# processing      NN
# is              VBZ
# interesting     JJ
# ,               ,
# In              IN
# LAB             NNP
# 5311LA          CD
